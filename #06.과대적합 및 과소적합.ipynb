# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaycold/tensorflow_tutorial/blob/main/%236.%EA%B3%BC%EB%8C%80%EC%A0%81%ED%95%A9%20%EB%B0%8F%20%EA%B3%BC%EC%86%8C%EC%A0%81%ED%95%A9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Load the Module

import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# %%
# IBDM Dataset Download

num_words = 1000

(train_data, train_labels), (test_data, test_labels) = keras.datasets.imdb.load_data(num_words=num_words)

def multi_hot_sequences(sequence, dimension) :
    results = np.zeros((len(sequence), dimension))
    for idx, value in enumerate(sequence) :
        results[idx, value] = 1
    return results

train_data = multi_hot_sequences(train_data, num_words)
test_data = multi_hot_sequences(test_data, num_words)
# Out:
# <string>:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/datasets/imdb.py:155: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_train, y_train = np.array(xs[:idx]), np.array(labels[:idx])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/datasets/imdb.py:156: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_test, y_test = np.array(xs[idx:]), np.array(labels[idx:])

# %%
train_data.shape
# Out:
# (25000, 1000)

# %% [markdown]
#     과대적합 막는 간단한 방법
#      - 모델 축소
#         - 학습 가능한 파라미터 수 줄이기

# %%
# Baseline Model

baseline_model = keras.Sequential([
                    keras.layers.Dense(16, activation = 'relu', input_shape = (num_words,)),
                    keras.layers.Dense(16, activation = 'relu'),
                    keras.layers.Dense(1, activation = 'sigmoid')
])

baseline_model.compile( optimizer = 'adam',
                        loss = 'binary_crossentropy',
                       metrics = ['accuracy', 'binary_crossentropy'])
baseline_model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_18 (Dense)             (None, 16)                16016
# _________________________________________________________________
# dense_19 (Dense)             (None, 16)                272
# _________________________________________________________________
# dense_20 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 16,305
# Trainable params: 16,305
# Non-trainable params: 0
# _________________________________________________________________

# %%
baseline_history = baseline_model.fit(train_data, train_labels,
                                      epochs = 20, 
                                      batch_size = 512,
                                      validation_data = (test_data, test_labels),
                                      verbose = 1)
# Out:
# Epoch 1/20
# 49/49 [==============================] - 1s 13ms/step - loss: 0.5854 - accuracy: 0.7016 - binary_crossentropy: 0.5854 - val_loss: 0.4394 - val_accuracy: 0.8108 - val_binary_crossentropy: 0.4394
# Epoch 2/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.3708 - accuracy: 0.8461 - binary_crossentropy: 0.3708 - val_loss: 0.3439 - val_accuracy: 0.8552 - val_binary_crossentropy: 0.3439
# Epoch 3/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.3224 - accuracy: 0.8673 - binary_crossentropy: 0.3224 - val_loss: 0.3313 - val_accuracy: 0.8589 - val_binary_crossentropy: 0.3313
# Epoch 4/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.3074 - accuracy: 0.8725 - binary_crossentropy: 0.3074 - val_loss: 0.3316 - val_accuracy: 0.8584 - val_binary_crossentropy: 0.3316
# Epoch 5/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.3011 - accuracy: 0.8760 - binary_crossentropy: 0.3011 - val_loss: 0.3278 - val_accuracy: 0.8605 - val_binary_crossentropy: 0.3278
# Epoch 6/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.2967 - accuracy: 0.8780 - binary_crossentropy: 0.2967 - val_loss: 0.3277 - val_accuracy: 0.8611 - val_binary_crossentropy: 0.3277
# Epoch 7/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.2909 - accuracy: 0.8790 - binary_crossentropy: 0.2909 - val_loss: 0.3343 - val_accuracy: 0.8563 - val_binary_crossentropy: 0.3343
# Epoch 8/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.2838 - accuracy: 0.8824 - binary_crossentropy: 0.2838 - val_loss: 0.3327 - val_accuracy: 0.8572 - val_binary_crossentropy: 0.3327
# Epoch 9/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.2782 - accuracy: 0.8857 - binary_crossentropy: 0.2782 - val_loss: 0.3311 - val_accuracy: 0.8602 - val_binary_crossentropy: 0.3311
# Epoch 10/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.2695 - accuracy: 0.8890 - binary_crossentropy: 0.2695 - val_loss: 0.3315 - val_accuracy: 0.8578 - val_binary_crossentropy: 0.3315
# Epoch 11/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.2606 - accuracy: 0.8925 - binary_crossentropy: 0.2606 - val_loss: 0.3338 - val_accuracy: 0.8560 - val_binary_crossentropy: 0.3338
# Epoch 12/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.2530 - accuracy: 0.8968 - binary_crossentropy: 0.2530 - val_loss: 0.3381 - val_accuracy: 0.8559 - val_binary_crossentropy: 0.3381
# Epoch 13/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.2444 - accuracy: 0.9007 - binary_crossentropy: 0.2444 - val_loss: 0.3445 - val_accuracy: 0.8519 - val_binary_crossentropy: 0.3445
# Epoch 14/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.2344 - accuracy: 0.9057 - binary_crossentropy: 0.2344 - val_loss: 0.3470 - val_accuracy: 0.8529 - val_binary_crossentropy: 0.3470
# Epoch 15/20
# 49/49 [==============================] - 0s 8ms/step - loss: 0.2265 - accuracy: 0.9089 - binary_crossentropy: 0.2265 - val_loss: 0.3533 - val_accuracy: 0.8523 - val_binary_crossentropy: 0.3533
# Epoch 16/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.2185 - accuracy: 0.9124 - binary_crossentropy: 0.2185 - val_loss: 0.3701 - val_accuracy: 0.8497 - val_binary_crossentropy: 0.3701
# Epoch 17/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.2101 - accuracy: 0.9153 - binary_crossentropy: 0.2101 - val_loss: 0.3723 - val_accuracy: 0.8494 - val_binary_crossentropy: 0.3723
# Epoch 18/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.2021 - accuracy: 0.9200 - binary_crossentropy: 0.2021 - val_loss: 0.3781 - val_accuracy: 0.8456 - val_binary_crossentropy: 0.3781
# Epoch 19/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.1939 - accuracy: 0.9240 - binary_crossentropy: 0.1939 - val_loss: 0.3841 - val_accuracy: 0.8470 - val_binary_crossentropy: 0.3841
# Epoch 20/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.1860 - accuracy: 0.9282 - binary_crossentropy: 0.1860 - val_loss: 0.3969 - val_accuracy: 0.8453 - val_binary_crossentropy: 0.3969

# %%
# Small model

smaller_model = keras.Sequential([
                    keras.layers.Dense(4, activation = 'relu', input_shape = (num_words,)),
                    keras.layers.Dense(4, activation = 'relu'),
                    keras.layers.Dense(1, activation = 'sigmoid')
])

smaller_model.compile( optimizer = 'adam',
                        loss = 'binary_crossentropy',
                       metrics = ['accuracy', 'binary_crossentropy'])
smaller_model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_21 (Dense)             (None, 4)                 4004
# _________________________________________________________________
# dense_22 (Dense)             (None, 4)                 20
# _________________________________________________________________
# dense_23 (Dense)             (None, 1)                 5
# =================================================================
# Total params: 4,029
# Trainable params: 4,029
# Non-trainable params: 0
# _________________________________________________________________

# %%
smaller_history = baseline_model.fit(train_data, train_labels,
                                      epochs = 20, 
                                      batch_size = 512,
                                      validation_data = (test_data, test_labels),
                                      verbose = 1)
# Out:
# Epoch 1/20
# 49/49 [==============================] - 1s 11ms/step - loss: 0.1789 - accuracy: 0.9326 - binary_crossentropy: 0.1789 - val_loss: 0.4075 - val_accuracy: 0.8439 - val_binary_crossentropy: 0.4075
# Epoch 2/20
# 49/49 [==============================] - 0s 10ms/step - loss: 0.1721 - accuracy: 0.9335 - binary_crossentropy: 0.1721 - val_loss: 0.4177 - val_accuracy: 0.8409 - val_binary_crossentropy: 0.4177
# Epoch 3/20
# 49/49 [==============================] - 0s 8ms/step - loss: 0.1660 - accuracy: 0.9388 - binary_crossentropy: 0.1660 - val_loss: 0.4331 - val_accuracy: 0.8401 - val_binary_crossentropy: 0.4331
# Epoch 4/20
# 49/49 [==============================] - 0s 10ms/step - loss: 0.1605 - accuracy: 0.9400 - binary_crossentropy: 0.1605 - val_loss: 0.4419 - val_accuracy: 0.8407 - val_binary_crossentropy: 0.4419
# Epoch 5/20
# 49/49 [==============================] - 0s 8ms/step - loss: 0.1523 - accuracy: 0.9455 - binary_crossentropy: 0.1523 - val_loss: 0.4491 - val_accuracy: 0.8391 - val_binary_crossentropy: 0.4491
# Epoch 6/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.1459 - accuracy: 0.9480 - binary_crossentropy: 0.1459 - val_loss: 0.4619 - val_accuracy: 0.8375 - val_binary_crossentropy: 0.4619
# Epoch 7/20
# 49/49 [==============================] - 0s 8ms/step - loss: 0.1399 - accuracy: 0.9513 - binary_crossentropy: 0.1399 - val_loss: 0.4793 - val_accuracy: 0.8362 - val_binary_crossentropy: 0.4793
# Epoch 8/20
# 49/49 [==============================] - 0s 8ms/step - loss: 0.1342 - accuracy: 0.9530 - binary_crossentropy: 0.1342 - val_loss: 0.4924 - val_accuracy: 0.8344 - val_binary_crossentropy: 0.4924
# Epoch 9/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.1294 - accuracy: 0.9558 - binary_crossentropy: 0.1294 - val_loss: 0.5113 - val_accuracy: 0.8328 - val_binary_crossentropy: 0.5113
# Epoch 10/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.1230 - accuracy: 0.9588 - binary_crossentropy: 0.1230 - val_loss: 0.5160 - val_accuracy: 0.8324 - val_binary_crossentropy: 0.5160
# Epoch 11/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.1191 - accuracy: 0.9604 - binary_crossentropy: 0.1191 - val_loss: 0.5372 - val_accuracy: 0.8341 - val_binary_crossentropy: 0.5372
# Epoch 12/20
# 49/49 [==============================] - 0s 8ms/step - loss: 0.1121 - accuracy: 0.9639 - binary_crossentropy: 0.1121 - val_loss: 0.5518 - val_accuracy: 0.8306 - val_binary_crossentropy: 0.5518
# Epoch 13/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.1082 - accuracy: 0.9656 - binary_crossentropy: 0.1082 - val_loss: 0.5698 - val_accuracy: 0.8296 - val_binary_crossentropy: 0.5698
# Epoch 14/20
# 49/49 [==============================] - 0s 8ms/step - loss: 0.1019 - accuracy: 0.9683 - binary_crossentropy: 0.1019 - val_loss: 0.5897 - val_accuracy: 0.8295 - val_binary_crossentropy: 0.5897
# Epoch 15/20
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0981 - accuracy: 0.9698 - binary_crossentropy: 0.0981 - val_loss: 0.6018 - val_accuracy: 0.8288 - val_binary_crossentropy: 0.6018
# Epoch 16/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0941 - accuracy: 0.9713 - binary_crossentropy: 0.0941 - val_loss: 0.6327 - val_accuracy: 0.8246 - val_binary_crossentropy: 0.6327
# Epoch 17/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0906 - accuracy: 0.9726 - binary_crossentropy: 0.0906 - val_loss: 0.6373 - val_accuracy: 0.8274 - val_binary_crossentropy: 0.6373
# Epoch 18/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0845 - accuracy: 0.9756 - binary_crossentropy: 0.0845 - val_loss: 0.6594 - val_accuracy: 0.8266 - val_binary_crossentropy: 0.6594
# Epoch 19/20
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0812 - accuracy: 0.9770 - binary_crossentropy: 0.0812 - val_loss: 0.6757 - val_accuracy: 0.8251 - val_binary_crossentropy: 0.6757
# Epoch 20/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0775 - accuracy: 0.9780 - binary_crossentropy: 0.0775 - val_loss: 0.6926 - val_accuracy: 0.8244 - val_binary_crossentropy: 0.6926

# %%
# Large model

bigger_model = keras.Sequential([
                    keras.layers.Dense(512, activation = 'relu', input_shape = (num_words,)),
                    keras.layers.Dense(512, activation = 'relu'),
                    keras.layers.Dense(1, activation = 'sigmoid')
])

bigger_model.compile( optimizer = 'adam',
                        loss = 'binary_crossentropy',
                       metrics = ['accuracy', 'binary_crossentropy'])
bigger_model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_24 (Dense)             (None, 512)               512512
# _________________________________________________________________
# dense_25 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_26 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 775,681
# Trainable params: 775,681
# Non-trainable params: 0
# _________________________________________________________________

# %%
bigger_history = baseline_model.fit(train_data, train_labels,
                                      epochs = 20, 
                                      batch_size = 512,
                                      validation_data = (test_data, test_labels),
                                      verbose = 1)
# Out:
# Epoch 1/20
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0743 - accuracy: 0.9798 - binary_crossentropy: 0.0743 - val_loss: 0.7163 - val_accuracy: 0.8250 - val_binary_crossentropy: 0.7163
# Epoch 2/20
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0694 - accuracy: 0.9818 - binary_crossentropy: 0.0694 - val_loss: 0.7354 - val_accuracy: 0.8232 - val_binary_crossentropy: 0.7354
# Epoch 3/20
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0668 - accuracy: 0.9826 - binary_crossentropy: 0.0668 - val_loss: 0.7563 - val_accuracy: 0.8224 - val_binary_crossentropy: 0.7563
# Epoch 4/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0639 - accuracy: 0.9838 - binary_crossentropy: 0.0639 - val_loss: 0.7710 - val_accuracy: 0.8239 - val_binary_crossentropy: 0.7710
# Epoch 5/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0594 - accuracy: 0.9860 - binary_crossentropy: 0.0594 - val_loss: 0.7966 - val_accuracy: 0.8226 - val_binary_crossentropy: 0.7966
# Epoch 6/20
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0556 - accuracy: 0.9876 - binary_crossentropy: 0.0556 - val_loss: 0.8150 - val_accuracy: 0.8217 - val_binary_crossentropy: 0.8150
# Epoch 7/20
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0517 - accuracy: 0.9889 - binary_crossentropy: 0.0517 - val_loss: 0.8478 - val_accuracy: 0.8198 - val_binary_crossentropy: 0.8478
# Epoch 8/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0509 - accuracy: 0.9886 - binary_crossentropy: 0.0509 - val_loss: 0.8573 - val_accuracy: 0.8194 - val_binary_crossentropy: 0.8573
# Epoch 9/20
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0468 - accuracy: 0.9910 - binary_crossentropy: 0.0468 - val_loss: 0.8805 - val_accuracy: 0.8195 - val_binary_crossentropy: 0.8805
# Epoch 10/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0445 - accuracy: 0.9911 - binary_crossentropy: 0.0445 - val_loss: 0.9100 - val_accuracy: 0.8202 - val_binary_crossentropy: 0.9100
# Epoch 11/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0422 - accuracy: 0.9922 - binary_crossentropy: 0.0422 - val_loss: 0.9317 - val_accuracy: 0.8192 - val_binary_crossentropy: 0.9317
# Epoch 12/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0389 - accuracy: 0.9934 - binary_crossentropy: 0.0389 - val_loss: 0.9521 - val_accuracy: 0.8177 - val_binary_crossentropy: 0.9521
# Epoch 13/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0365 - accuracy: 0.9943 - binary_crossentropy: 0.0365 - val_loss: 0.9695 - val_accuracy: 0.8176 - val_binary_crossentropy: 0.9695
# Epoch 14/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0352 - accuracy: 0.9942 - binary_crossentropy: 0.0352 - val_loss: 0.9974 - val_accuracy: 0.8178 - val_binary_crossentropy: 0.9974
# Epoch 15/20
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0328 - accuracy: 0.9949 - binary_crossentropy: 0.0328 - val_loss: 1.0270 - val_accuracy: 0.8166 - val_binary_crossentropy: 1.0270
# Epoch 16/20
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0309 - accuracy: 0.9957 - binary_crossentropy: 0.0309 - val_loss: 1.0399 - val_accuracy: 0.8166 - val_binary_crossentropy: 1.0399
# Epoch 17/20
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0290 - accuracy: 0.9959 - binary_crossentropy: 0.0290 - val_loss: 1.0566 - val_accuracy: 0.8160 - val_binary_crossentropy: 1.0566
# Epoch 18/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0264 - accuracy: 0.9968 - binary_crossentropy: 0.0264 - val_loss: 1.0859 - val_accuracy: 0.8170 - val_binary_crossentropy: 1.0859
# Epoch 19/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0248 - accuracy: 0.9974 - binary_crossentropy: 0.0248 - val_loss: 1.1147 - val_accuracy: 0.8152 - val_binary_crossentropy: 1.1147
# Epoch 20/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0233 - accuracy: 0.9977 - binary_crossentropy: 0.0233 - val_loss: 1.1251 - val_accuracy: 0.8156 - val_binary_crossentropy: 1.1251

# %%
# Compare with 3 Model

def plot_history(histories, key='binary_crossentropy') :
    plt.figure(figsize=(16,10))

    for name, history in histories :
        val = plt.plot(history.epoch, history.history['val_'+key],
                       '--', label= name.title() + ' val')
        plt.plot(history.epoch, history.history[key], 
                 color = val[0].get_color(),
                 label = name.title() + ' Train')
    plt.xlabel('Epochs')
    plt.ylabel(key.replace('_',' ').title())
    plt.legend()

    plt.xlim([0,max(history.epoch)])

plot_history([('baseline', baseline_history),
              ('smaller', smaller_history),
              ('bigger', bigger_history)])

# %% [markdown]
#     # 과대적합 방지
#         - 간단한 모델은 복잡한 것 보다 과대적합이 되는 경향이 작음
#         - 간단한 모델 = 파라미터의 분포 entropy가 작은 모델
#           -> 가중치가 작은 값을 갖도록 복잡도에 제약 걸기 : weight decay
#         - L1 & L2 (L2가 주로 사용)

# %%
# L2 Weight decay

l2_model = keras.models.Sequential([
                keras.layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.001), activation = 'relu', input_shape = (num_words,)),
                keras.layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.001), activation = 'relu'),
                keras.layers.Dense(1, activation='sigmoid')

])

l2_model.compile(loss = 'binary_crossentropy',
                 optimizer = 'adam',
                 metrics = ['accuracy', 'binary_crossentropy'])
l2_model_history = l2_model.fit(train_data, train_labels,
                                validation_data = (test_data, test_labels),
                                epochs = 20, 
                                batch_size = 512,
                                verbose = 1)
# Out:
# Epoch 1/20
# 49/49 [==============================] - 1s 14ms/step - loss: 0.6243 - accuracy: 0.7113 - binary_crossentropy: 0.5824 - val_loss: 0.4824 - val_accuracy: 0.8155 - val_binary_crossentropy: 0.4426
# Epoch 2/20
# 49/49 [==============================] - 0s 8ms/step - loss: 0.4163 - accuracy: 0.8444 - binary_crossentropy: 0.3767 - val_loss: 0.3900 - val_accuracy: 0.8510 - val_binary_crossentropy: 0.3508
# Epoch 3/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.3627 - accuracy: 0.8666 - binary_crossentropy: 0.3239 - val_loss: 0.3699 - val_accuracy: 0.8599 - val_binary_crossentropy: 0.3317
# Epoch 4/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.3475 - accuracy: 0.8725 - binary_crossentropy: 0.3099 - val_loss: 0.3701 - val_accuracy: 0.8576 - val_binary_crossentropy: 0.3331
# Epoch 5/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.3419 - accuracy: 0.8737 - binary_crossentropy: 0.3054 - val_loss: 0.3630 - val_accuracy: 0.8608 - val_binary_crossentropy: 0.3271
# Epoch 6/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.3354 - accuracy: 0.8772 - binary_crossentropy: 0.3000 - val_loss: 0.3654 - val_accuracy: 0.8596 - val_binary_crossentropy: 0.3305
# Epoch 7/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.3325 - accuracy: 0.8760 - binary_crossentropy: 0.2981 - val_loss: 0.3600 - val_accuracy: 0.8606 - val_binary_crossentropy: 0.3260
# Epoch 8/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.3285 - accuracy: 0.8788 - binary_crossentropy: 0.2948 - val_loss: 0.3644 - val_accuracy: 0.8587 - val_binary_crossentropy: 0.3312
# Epoch 9/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.3257 - accuracy: 0.8803 - binary_crossentropy: 0.2927 - val_loss: 0.3579 - val_accuracy: 0.8602 - val_binary_crossentropy: 0.3252
# Epoch 10/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.3209 - accuracy: 0.8800 - binary_crossentropy: 0.2884 - val_loss: 0.3568 - val_accuracy: 0.8605 - val_binary_crossentropy: 0.3246
# Epoch 11/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.3177 - accuracy: 0.8810 - binary_crossentropy: 0.2856 - val_loss: 0.3565 - val_accuracy: 0.8599 - val_binary_crossentropy: 0.3247
# Epoch 12/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.3148 - accuracy: 0.8816 - binary_crossentropy: 0.2830 - val_loss: 0.3566 - val_accuracy: 0.8604 - val_binary_crossentropy: 0.3250
# Epoch 13/20
# 49/49 [==============================] - 0s 8ms/step - loss: 0.3106 - accuracy: 0.8840 - binary_crossentropy: 0.2790 - val_loss: 0.3554 - val_accuracy: 0.8599 - val_binary_crossentropy: 0.3238
# Epoch 14/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.3077 - accuracy: 0.8850 - binary_crossentropy: 0.2762 - val_loss: 0.3585 - val_accuracy: 0.8598 - val_binary_crossentropy: 0.3270
# Epoch 15/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.3040 - accuracy: 0.8876 - binary_crossentropy: 0.2725 - val_loss: 0.3571 - val_accuracy: 0.8596 - val_binary_crossentropy: 0.3256
# Epoch 16/20
# 49/49 [==============================] - 0s 8ms/step - loss: 0.3006 - accuracy: 0.8883 - binary_crossentropy: 0.2690 - val_loss: 0.3564 - val_accuracy: 0.8598 - val_binary_crossentropy: 0.3248
# Epoch 17/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.2976 - accuracy: 0.8896 - binary_crossentropy: 0.2658 - val_loss: 0.3591 - val_accuracy: 0.8586 - val_binary_crossentropy: 0.3273
# Epoch 18/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.2937 - accuracy: 0.8926 - binary_crossentropy: 0.2617 - val_loss: 0.3595 - val_accuracy: 0.8598 - val_binary_crossentropy: 0.3274
# Epoch 19/20
# 49/49 [==============================] - 0s 8ms/step - loss: 0.2905 - accuracy: 0.8945 - binary_crossentropy: 0.2582 - val_loss: 0.3619 - val_accuracy: 0.8593 - val_binary_crossentropy: 0.3295
# Epoch 20/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.2874 - accuracy: 0.8956 - binary_crossentropy: 0.2548 - val_loss: 0.3686 - val_accuracy: 0.8579 - val_binary_crossentropy: 0.3357

# %%
plot_history([('baseline', baseline_history),
              ('l2', l2_model_history)])

# %% [markdown]
#     # 과대적합 방지
#         - 드롭아웃 추가하기
#         - [0.2, 0.5, 1.3, 0.8, 1.1] -> [0, 0.5, 1.3, 0, 1.1]
#         - 비율 = 0이 되는 비율
#         - 주로 0.2~0.5

# %%
dpt_model = keras.models.Sequential([
                keras.layers.Dense(16, activation='relu', input_shape= (num_words,)),
                keras.layers.Dropout(0.5),
                keras.layers.Dense(16, activation='relu'), 
                keras.layers.Dropout(0.5),
                keras.layers.Dense(1, activation='sigmoid')
])

dpt_model.compile(optimizer = 'adam',
                  loss = 'binary_crossentropy',
                  metrics = ['accuracy', 'binary_crossentropy'])
dpt_model_history = dpt_model.fit(train_data, train_labels,
              validation_data = (test_data, test_labels),
              epochs = 20,
              verbose = 1,
              batch_size = 512)
# Out:
# Epoch 1/20
# 49/49 [==============================] - 1s 14ms/step - loss: 0.6774 - accuracy: 0.5704 - binary_crossentropy: 0.6774 - val_loss: 0.6319 - val_accuracy: 0.7595 - val_binary_crossentropy: 0.6319
# Epoch 2/20
# 49/49 [==============================] - 0s 10ms/step - loss: 0.5927 - accuracy: 0.7058 - binary_crossentropy: 0.5927 - val_loss: 0.5040 - val_accuracy: 0.8272 - val_binary_crossentropy: 0.5040
# Epoch 3/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.5091 - accuracy: 0.7811 - binary_crossentropy: 0.5091 - val_loss: 0.4230 - val_accuracy: 0.8437 - val_binary_crossentropy: 0.4230
# Epoch 4/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.4552 - accuracy: 0.8165 - binary_crossentropy: 0.4552 - val_loss: 0.3732 - val_accuracy: 0.8523 - val_binary_crossentropy: 0.3732
# Epoch 5/20
# 49/49 [==============================] - 0s 8ms/step - loss: 0.4222 - accuracy: 0.8327 - binary_crossentropy: 0.4222 - val_loss: 0.3513 - val_accuracy: 0.8562 - val_binary_crossentropy: 0.3513
# Epoch 6/20
# 49/49 [==============================] - 0s 10ms/step - loss: 0.4018 - accuracy: 0.8424 - binary_crossentropy: 0.4018 - val_loss: 0.3391 - val_accuracy: 0.8580 - val_binary_crossentropy: 0.3391
# Epoch 7/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.3828 - accuracy: 0.8510 - binary_crossentropy: 0.3828 - val_loss: 0.3346 - val_accuracy: 0.8582 - val_binary_crossentropy: 0.3346
# Epoch 8/20
# 49/49 [==============================] - 0s 10ms/step - loss: 0.3716 - accuracy: 0.8561 - binary_crossentropy: 0.3716 - val_loss: 0.3318 - val_accuracy: 0.8577 - val_binary_crossentropy: 0.3318
# Epoch 9/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.3645 - accuracy: 0.8597 - binary_crossentropy: 0.3645 - val_loss: 0.3285 - val_accuracy: 0.8588 - val_binary_crossentropy: 0.3285
# Epoch 10/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.3602 - accuracy: 0.8597 - binary_crossentropy: 0.3602 - val_loss: 0.3283 - val_accuracy: 0.8584 - val_binary_crossentropy: 0.3283
# Epoch 11/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.3535 - accuracy: 0.8647 - binary_crossentropy: 0.3535 - val_loss: 0.3309 - val_accuracy: 0.8572 - val_binary_crossentropy: 0.3309
# Epoch 12/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.3470 - accuracy: 0.8686 - binary_crossentropy: 0.3470 - val_loss: 0.3282 - val_accuracy: 0.8558 - val_binary_crossentropy: 0.3282
# Epoch 13/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.3380 - accuracy: 0.8694 - binary_crossentropy: 0.3380 - val_loss: 0.3283 - val_accuracy: 0.8571 - val_binary_crossentropy: 0.3283
# Epoch 14/20
# 49/49 [==============================] - 0s 10ms/step - loss: 0.3357 - accuracy: 0.8719 - binary_crossentropy: 0.3357 - val_loss: 0.3285 - val_accuracy: 0.8568 - val_binary_crossentropy: 0.3285
# Epoch 15/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.3348 - accuracy: 0.8733 - binary_crossentropy: 0.3348 - val_loss: 0.3297 - val_accuracy: 0.8570 - val_binary_crossentropy: 0.3297
# Epoch 16/20
# 49/49 [==============================] - 0s 10ms/step - loss: 0.3262 - accuracy: 0.8758 - binary_crossentropy: 0.3262 - val_loss: 0.3298 - val_accuracy: 0.8579 - val_binary_crossentropy: 0.3298
# Epoch 17/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.3232 - accuracy: 0.8777 - binary_crossentropy: 0.3232 - val_loss: 0.3299 - val_accuracy: 0.8569 - val_binary_crossentropy: 0.3299
# Epoch 18/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.3230 - accuracy: 0.8816 - binary_crossentropy: 0.3230 - val_loss: 0.3326 - val_accuracy: 0.8558 - val_binary_crossentropy: 0.3326
# Epoch 19/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.3205 - accuracy: 0.8816 - binary_crossentropy: 0.3205 - val_loss: 0.3316 - val_accuracy: 0.8574 - val_binary_crossentropy: 0.3316
# Epoch 20/20
# 49/49 [==============================] - 0s 9ms/step - loss: 0.3110 - accuracy: 0.8835 - binary_crossentropy: 0.3110 - val_loss: 0.3331 - val_accuracy: 0.8560 - val_binary_crossentropy: 0.3331

# %%
plot_history([('baseline', baseline_history),
              ('dropout', dpt_model_history)])

# %%
# Conclusion

# to avoid the overfitting
# - Gathering more data
# - Reducing the Network memories
# - Weight Decaying
# - Dropout layers
